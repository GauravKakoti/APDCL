# %% [markdown]
# # Part 1

# %%
import pandas as pd
import numpy as np

# %%
c_dtr=pd.read_csv("c_dtr_details.csv")

# %%
c_dtr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43135 entries, 0 to 44619
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      43135 non-null  int64
#  1   Cons No    43135 non-null  int64
#  2   Dtr No     43135 non-null  int64
#  3   Category   43135 non-null  int64
#  4   Load       43135 non-null  float64
#  5   Latitude   43135 non-null  float64
#  6   Longitude  43135 non-null  float64
# dtypes: float64(3), int64(4)
# memory usage: 2.6 MB

# %%
c_dtr.sort_values(by=["Dtr No"],inplace=True)

# %%
#c_dtr.reset_index(drop= True, inplace = True)

# %%
c_dtr.head(100)
# Out:
#     index       Cons No  Dtr No  Category  Load   Latitude  Longitude
# 0   42908  133010071108      18        46  1.00  24.982266  92.514997
# 16  12108  133000017918      18        46  1.00  24.983908  92.516930
# 1    2649  133000003859      18        48  0.68  24.980293  92.522114
# 2    2648  133000003858      18        48  0.66  24.980293  92.522114
# 3    2627  133000003826      18        48  0.48  24.983333  92.519245
# ..    ...           ...     ...       ...   ...        ...        ...
# 95  43869  133010072390      22        46  1.00  24.941693  92.654450
# 96  17527  133000024392      22        46  0.58  24.926813  92.636763
# 97  30301  133000038798      22        46  1.00  24.938222  92.638706
# 98  17536  133000024401      22        46  0.22  24.940827  92.639420
# 94  20128  133000027421      22        46  1.00  24.936774  92.639245
#
# [100 rows x 7 columns]

# %%
c_dtr.dropna(inplace=True)

# %%
c_dtr.reset_index(drop= True, inplace = True)
c_dtr
# Out:
#        index       Cons No  Dtr No  Category  Load   Latitude  Longitude
# 0      42908  133010071108      18        46  1.00  24.982266  92.514997
# 1      12108  133000017918      18        46  1.00  24.983908  92.516930
# 2       2649  133000003859      18        48  0.68  24.980293  92.522114
# 3       2648  133000003858      18        48  0.66  24.980293  92.522114
# 4       2627  133000003826      18        48  0.48  24.983333  92.519245
# ...      ...           ...     ...       ...   ...        ...        ...
# 43130  44511  133010073468    2260        43  0.49  24.958527  92.560196
# 43131  13494  133000019621    2260        46  0.06  24.961067  92.563293
# 43132  31342  133000039986    2260        46  0.49  24.961132  92.563725
# 43133  31080  133000039675    2261        43  0.49  25.009934  92.455315
# 43134  31082  133000039677    2261        43  0.49  25.015670  92.453973
#
# [43135 rows x 7 columns]

# %%
## what we covered
#     * sort dF acc to DTR no
#     * dropped all null columns
#     * reset index

# %% [markdown]
# # cumulative sum of LOAD according to DTR No

# %%
# df['cumsum_sales'] = df.groupby(['store'])['sales'].cumsum()

# %%
c_dtr['cumulative sum'] = c_dtr.groupby(['Dtr No'])['Load'].cumsum()

# %%
c_dtr
# Out:
#        index       Cons No  Dtr No  Category  Load   Latitude  Longitude  \
# 0      42908  133010071108      18        46  1.00  24.982266  92.514997
# 1      12108  133000017918      18        46  1.00  24.983908  92.516930
# 2       2649  133000003859      18        48  0.68  24.980293  92.522114
# 3       2648  133000003858      18        48  0.66  24.980293  92.522114
# 4       2627  133000003826      18        48  0.48  24.983333  92.519245
# ...      ...           ...     ...       ...   ...        ...        ...
# 43130  44511  133010073468    2260        43  0.49  24.958527  92.560196
# 43131  13494  133000019621    2260        46  0.06  24.961067  92.563293
# 43132  31342  133000039986    2260        46  0.49  24.961132  92.563725
# 43133  31080  133000039675    2261        43  0.49  25.009934  92.455315
# 43134  31082  133000039677    2261        43  0.49  25.015670  92.453973
#
#        cumulative sum
# 0                1.00
# 1                2.00
# ...

# %%
c_dtr.head(75)
# Out:
#     index       Cons No  Dtr No  Category  Load   Latitude  Longitude  \
# 0   42908  133010071108      18        46  1.00  24.982266  92.514997
# 1   12108  133000017918      18        46  1.00  24.983908  92.516930
# 2    2649  133000003859      18        48  0.68  24.980293  92.522114
# 3    2648  133000003858      18        48  0.66  24.980293  92.522114
# 4    2627  133000003826      18        48  0.48  24.983333  92.519245
# ..    ...           ...     ...       ...   ...        ...        ...
# 70  13858  133000020200      18        46  1.00  24.981843  92.518091
# 71  13847  133000020187      18        46  0.06  24.982198  92.519019
# 72   4315  133000006109      18        48  1.00  24.983750  92.519251
# 73  17530  133000024395      22        46  0.52  24.935701  92.637073
# 74  17528  133000024393      22        46  0.62  24.935701  92.637073
#
#     cumulative sum
# 0             1.00
# 1             2.00
# 2             2.68
# 3             3.34
# 4             3.82
# ...

# %%
c_dtr.to_csv("c_dtr_with_cumulative_sum.csv")

# %%
# this column gives the total cumulative sum of each unique Dtr No
c_dtr['dup_cum_sum'] = c_dtr.groupby('Dtr No')['cumulative sum'].transform('max')

# %%
#del c_dtr["dep_cum_sum"]

# %%
c_dtr.head(75)
# Out:
#     index       Cons No  Dtr No  Category  Load   Latitude  Longitude  \
# 0   42908  133010071108      18        46  1.00  24.982266  92.514997
# 1   12108  133000017918      18        46  1.00  24.983908  92.516930
# 2    2649  133000003859      18        48  0.68  24.980293  92.522114
# 3    2648  133000003858      18        48  0.66  24.980293  92.522114
# 4    2627  133000003826      18        48  0.48  24.983333  92.519245
# ..    ...           ...     ...       ...   ...        ...        ...
# 70  13858  133000020200      18        46  1.00  24.981843  92.518091
# 71  13847  133000020187      18        46  0.06  24.982198  92.519019
# 72   4315  133000006109      18        48  1.00  24.983750  92.519251
# 73  17530  133000024395      22        46  0.52  24.935701  92.637073
# 74  17528  133000024393      22        46  0.62  24.935701  92.637073
#
#     cumulative sum  dup_cum_sum
# 0             1.00        56.39
# 1             2.00        56.39
# ...

# %% [markdown]
# ## creating another data Frame with "Dtr no" and "Cumulative sum"

# %%
data = [c_dtr["Dtr No"], c_dtr["dup_cum_sum"]]

headers = ["Dtr No2", "Total Load"]

cum_sum = pd.concat(data, axis=1, keys=headers)

# %%
cum_sum
# Out:
#        Dtr No2  Total Load
# 0           18       56.39
# 1           18       56.39
# 2           18       56.39
# 3           18       56.39
# 4           18       56.39
# ...        ...         ...
# 43130     2260       19.59
# 43131     2260       19.59
# 43132     2260       19.59
# 43133     2261        0.98
# 43134     2261        0.98
#
# [43135 rows x 2 columns]

# %%
cum_sum.drop_duplicates(subset=["Dtr No2"], inplace=True, ignore_index= True)

# %%
cum_sum
# Out:
#      Dtr No2  Total Load
# 0         18       56.39
# 1         22       20.95
# 2         43      119.91
# 3         44       58.06
# 4         46       48.92
# ..       ...         ...
# 618     2247       33.41
# 619     2254        1.00
# 620     2255        1.00
# 621     2260       19.59
# 622     2261        0.98
#
# [623 rows x 2 columns]

# %%
cum_sum.to_csv("c_dtr_sum.csv")

# %% [markdown]
# ------------------------------------
#
# # Part 2

# %%
dtr_details = pd.read_csv("dtr_details.csv")

# %%
dtr_details.shape
# Out:
# (321, 7)

# %%
dtr_details.head(100)
# Out:
#     Sub Div Code  Dtr No                      DTR Name  Feeder No Capacity  \
# 0            133      18                    018-paikan          5  100 kVA
# 1            133      44                    044-KHELMA          2  63  kVA
# 2            133      46                 046-CRAIGPARK          5  63  kVA
# 3            133      50                   050-9BPL II          2  25  kVA
# 4            133      54                     054-BPR 1          9  63  kVA
# ..           ...     ...                           ...        ...      ...
# 95           133     204            204-CHOLIGRAM 63KV          5  63  kVA
# 96           133    2041     SonapurPTI(Kunagram)25KVA        201  25  kVA
# 97           133    2042  SunapurPT-i(NearSchool)25KVA        201  25  kVA
# 98           133    2045  Sonapur PT I(Dispur) 100 kva        201  100 kVA
# 99           133     205               205-GOBINDOKUPA          5  25  kVA
#
#      Latitude  Longitude
# 0   24.982307  92.521000
# ...

# %%
dtr_details.sort_values(by=["Dtr No"],inplace=True)

# %%
dtr_details.head(100)
# Out:
#      Sub Div Code  Dtr No                                      DTR Name  \
# 0             133      18                                    018-paikan
# 1             133      44                                    044-KHELMA
# 2             133      46                                 046-CRAIGPARK
# 3             133      50                                   050-9BPL II
# 4             133      54                                     054-BPR 1
# ..            ...     ...                                           ...
# 201           133     308               Sundhura near Kalain Bagan down
# 202           133     311  311-Behara Pt V (Kalacheri) (Dindayal) DT- 1
# 203           133     324              324-Chandinagar 25 kva(Dindayal)
# 204           133     327                  327-Rongpur 25 kva(Dindayal)
# 205           133     328             328-Gobindapur-I 25 kva(Dindayal)
#
#      Feeder No Capacity   Latitude  Longitude
# 0            5  100 kVA  24.982307  92.521000
# ...

# %%
dtr_details.dropna(inplace = True)

# %%
dtr_details.reset_index(drop= True, inplace = True)

# %%
cum_sum
# Out:
#      Dtr No2  Total Load
# 0         18       56.39
# 1         22       20.95
# 2         43      119.91
# 3         44       58.06
# 4         46       48.92
# ..       ...         ...
# 618     2247       33.41
# 619     2254        1.00
# 620     2255        1.00
# 621     2260       19.59
# 622     2261        0.98
#
# [623 rows x 2 columns]

# %%
dtr_details
# Out:
#      Sub Div Code  Dtr No                     DTR Name  Feeder No Capacity  \
# 0             133      18                   018-paikan          5  100 kVA
# 1             133      44                   044-KHELMA          2  63  kVA
# 2             133      46                046-CRAIGPARK          5  63  kVA
# 3             133      50                  050-9BPL II          2  25  kVA
# 4             133      54                    054-BPR 1          9  63  kVA
# ..            ...     ...                          ...        ...      ...
# 316           133    2243            NATANPUR DDUGJY21          2  25  kVA
# 317           133    2244  GOBINDAKUPA PAIKAN DDUGJY21          5  25  kVA
# 318           133    2246              DUDPUR LAMARGAM          7  25  kVA
# 319           133    2252                 GUMRA BAGAAN          5  63  kVA
# 320           133    2255    BOROITOLI NEAR DIGABOR TE          2  16  kVA
#
#       Latitude  Longitude
# 0    24.982307  92.521000
# ...

# %%
# there is a problem of insufficient data (DTR No) in this data set
# 321 vs 623

# %% [markdown]
# ## manipulating data accourdingly

# %%
np.random.seed(0)
test_set = np.random.rand(302,1)

# %%
test_set
# Out:
# array([[0.5488135 ],
#        [0.71518937],
#        [0.60276338],
#        [0.54488318],
#        [0.4236548 ],
#        [0.64589411],
#        [0.43758721],
#        [0.891773  ],
#        [0.96366276],
#        [0.38344152],
#        [0.79172504],
#        [0.52889492],
#        [0.56804456],
#        [0.92559664],
#        [0.07103606],
#        [0.0871293 ],
#        [0.0202184 ],
#        [0.83261985],
#        [0.77815675],
#        [0.87001215],
#        [0.97861834],
#        [0.79915856],
#        [0.46147936],
#        [0.78052918],
#        [0.11827443],
#        [0.63992102],
#        [0.14335329],
#        [0.94466892],
#        [0.52184832],
#        [0.41466194],
#        [0.26455561],
#        [0.77423369],
#        [0.45615033],
#        [0.56843395],
#        [0.0187898 ],
#        [0.6176355 ],
#        [0.61209572],
#        [0.616934  ],
#        [0.94374808],
#        [0.6818203 ],
#        [0.3595079 ],
#        [0.43703195],
#        [0.6976312 ],
# ...

# %%
test_df = pd.DataFrame(test_set,columns=["Dtr No"])
test_df
# Out:
#        Dtr No
# 0    0.548814
# 1    0.715189
# 2    0.602763
# 3    0.544883
# 4    0.423655
# ..        ...
# 297  0.862192
# 298  0.972919
# 299  0.960835
# 300  0.906555
# 301  0.774047
#
# [302 rows x 1 columns]

# %%
dtr_details
# Out:
#      Sub Div Code  Dtr No                     DTR Name  Feeder No Capacity  \
# 0             133      18                   018-paikan          5  100 kVA
# 1             133      44                   044-KHELMA          2  63  kVA
# 2             133      46                046-CRAIGPARK          5  63  kVA
# 3             133      50                  050-9BPL II          2  25  kVA
# 4             133      54                    054-BPR 1          9  63  kVA
# ..            ...     ...                          ...        ...      ...
# 316           133    2243            NATANPUR DDUGJY21          2  25  kVA
# 317           133    2244  GOBINDAKUPA PAIKAN DDUGJY21          5  25  kVA
# 318           133    2246              DUDPUR LAMARGAM          7  25  kVA
# 319           133    2252                 GUMRA BAGAAN          5  63  kVA
# 320           133    2255    BOROITOLI NEAR DIGABOR TE          2  16  kVA
#
#       Latitude  Longitude
# 0    24.982307  92.521000
# ...

# %%
#dtr_details["Random Data"]=test_df

# %%
dtr_details
# Out:
#      Sub Div Code    Dtr No                     DTR Name  Feeder No Capacity  \
# 0             133  0.548814                   018-paikan          5  100 kVA
# 1             133  0.715189                   044-KHELMA          2  63  kVA
# 2             133  0.602763                046-CRAIGPARK          5  63  kVA
# 3             133  0.544883                  050-9BPL II          2  25  kVA
# 4             133  0.423655                    054-BPR 1          9  63  kVA
# ..            ...       ...                          ...        ...      ...
# 316           133       NaN            NATANPUR DDUGJY21          2  25  kVA
# 317           133       NaN  GOBINDAKUPA PAIKAN DDUGJY21          5  25  kVA
# 318           133       NaN              DUDPUR LAMARGAM          7  25  kVA
# 319           133       NaN                 GUMRA BAGAAN          5  63  kVA
# 320           133       NaN    BOROITOLI NEAR DIGABOR TE          2  16  kVA
#
# ...

# %%
frames = [dtr_details, test_df ]

result = pd.concat(frames)

# %%
result
# Out:
#      Sub Div Code     Dtr No       DTR Name  Feeder No Capacity   Latitude  \
# 0           133.0  18.000000     018-paikan        5.0  100 kVA  24.982307
# 1           133.0  44.000000     044-KHELMA        2.0  63  kVA  24.953685
# 2           133.0  46.000000  046-CRAIGPARK        5.0  63  kVA  25.008613
# 3           133.0  50.000000    050-9BPL II        2.0  25  kVA  24.999775
# 4           133.0  54.000000      054-BPR 1        9.0  63  kVA  24.907980
# ..            ...        ...            ...        ...      ...        ...
# 297           NaN   0.862192            NaN        NaN      NaN        NaN
# 298           NaN   0.972919            NaN        NaN      NaN        NaN
# 299           NaN   0.960835            NaN        NaN      NaN        NaN
# 300           NaN   0.906555            NaN        NaN      NaN        NaN
# 301           NaN   0.774047            NaN        NaN      NaN        NaN
#
#      Longitude
# 0    92.521000
# 1    92.499068
# 2    92.525782
# ...

# %%
result.reset_index(drop= True, inplace = True)

# %%
result
# Out:
#      Sub Div Code     Dtr No       DTR Name  Feeder No Capacity   Latitude  \
# 0           133.0  18.000000     018-paikan        5.0  100 kVA  24.982307
# 1           133.0  44.000000     044-KHELMA        2.0  63  kVA  24.953685
# 2           133.0  46.000000  046-CRAIGPARK        5.0  63  kVA  25.008613
# 3           133.0  50.000000    050-9BPL II        2.0  25  kVA  24.999775
# 4           133.0  54.000000      054-BPR 1        9.0  63  kVA  24.907980
# ..            ...        ...            ...        ...      ...        ...
# 618           NaN   0.862192            NaN        NaN      NaN        NaN
# 619           NaN   0.972919            NaN        NaN      NaN        NaN
# 620           NaN   0.960835            NaN        NaN      NaN        NaN
# 621           NaN   0.906555            NaN        NaN      NaN        NaN
# 622           NaN   0.774047            NaN        NaN      NaN        NaN
#
#      Longitude
# 0    92.521000
# 1    92.499068
# 2    92.525782
# ...

# %%
cum_sum
# Out:
#      Dtr No2  Total Load
# 0         18       56.39
# 1         22       20.95
# 2         43      119.91
# 3         44       58.06
# 4         46       48.92
# ..       ...         ...
# 618     2247       33.41
# 619     2254        1.00
# 620     2255        1.00
# 621     2260       19.59
# 622     2261        0.98
#
# [623 rows x 2 columns]

# %%
#df1['price_diff'] = np.where(df1['price_1'] == df2['price_2'], 0, df1['price_1'] - df2['price_2'])
#result("x") = np.where(result['Dtr No'] == cum_sum['Dtr No'], 1, 0)

# %%
result['Dtr No'].isin(cum_sum['Dtr No']).value_counts()
# Out:
# False    336
# True     287
# Name: Dtr No, dtype: int64

# %%
287+336
# Out:
# 623

# %%
result
# Out:
#      Sub Div Code     Dtr No       DTR Name  Feeder No Capacity   Latitude  \
# 0           133.0  18.000000     018-paikan        5.0  100 kVA  24.982307
# 1           133.0  44.000000     044-KHELMA        2.0  63  kVA  24.953685
# 2           133.0  46.000000  046-CRAIGPARK        5.0  63  kVA  25.008613
# 3           133.0  50.000000    050-9BPL II        2.0  25  kVA  24.999775
# 4           133.0  54.000000      054-BPR 1        9.0  63  kVA  24.907980
# ..            ...        ...            ...        ...      ...        ...
# 618           NaN   0.862192            NaN        NaN      NaN        NaN
# 619           NaN   0.972919            NaN        NaN      NaN        NaN
# 620           NaN   0.960835            NaN        NaN      NaN        NaN
# 621           NaN   0.906555            NaN        NaN      NaN        NaN
# 622           NaN   0.774047            NaN        NaN      NaN        NaN
#
#      Longitude
# 0    92.521000
# 1    92.499068
# 2    92.525782
# ...

# %%
result_2 = pd.concat([cum_sum, result], axis=1, join='outer')

# %%
result_2[("Dtr No")] = result_2[("Dtr No")].astype(int)
result_2
# Out:
#      Dtr No2  Total Load  Sub Div Code  Dtr No       DTR Name  Feeder No  \
# 0         18       56.39         133.0      18     018-paikan        5.0
# 1         22       20.95         133.0      44     044-KHELMA        2.0
# 2         43      119.91         133.0      46  046-CRAIGPARK        5.0
# 3         44       58.06         133.0      50    050-9BPL II        2.0
# 4         46       48.92         133.0      54      054-BPR 1        9.0
# ..       ...         ...           ...     ...            ...        ...
# 618     2247       33.41           NaN       0            NaN        NaN
# 619     2254        1.00           NaN       0            NaN        NaN
# 620     2255        1.00           NaN       0            NaN        NaN
# 621     2260       19.59           NaN       0            NaN        NaN
# 622     2261        0.98           NaN       0            NaN        NaN
#
#     Capacity   Latitude  Longitude
# 0    100 kVA  24.982307  92.521000
# ...

# %%
result_2
# Out:
#      Dtr No2  Total Load  Sub Div Code  Dtr No       DTR Name  Feeder No  \
# 0         18       56.39         133.0      18     018-paikan        5.0
# 1         22       20.95         133.0      44     044-KHELMA        2.0
# 2         43      119.91         133.0      46  046-CRAIGPARK        5.0
# 3         44       58.06         133.0      50    050-9BPL II        2.0
# 4         46       48.92         133.0      54      054-BPR 1        9.0
# ..       ...         ...           ...     ...            ...        ...
# 618     2247       33.41           NaN       0            NaN        NaN
# 619     2254        1.00           NaN       0            NaN        NaN
# 620     2255        1.00           NaN       0            NaN        NaN
# 621     2260       19.59           NaN       0            NaN        NaN
# 622     2261        0.98           NaN       0            NaN        NaN
#
#     Capacity   Latitude  Longitude
# 0    100 kVA  24.982307  92.521000
# ...

# %%
#  for x in range(623):
#      result_2['Counter'] = result_2.apply(lambda x: x['Dtr No2'] if x['Dtr No2'] == x['Dtr No'] else np.nan, axis=1)

# %%
result_2.dtypes
# Out:
# Dtr No2           int64
# Total Load      float64
# Sub Div Code    float64
# Dtr No            int32
# DTR Name         object
# Feeder No       float64
# Capacity         object
# Latitude        float64
# Longitude       float64
# dtype: object

# %%
#result_2["bool"]=result_2[result_2.duplicated(subset=['Dtr No','Dtr no2'])]
# result_2

# %%
for i, row in result_2.iterrows():
     for j, row in result_2.iterrows():

# %%
# result_2["comparison_column"] = np.where(result_2["Dtr No"] == result_2["Dtr No2"], True, False)

# %%
result_2
# Out:
#      Dtr No2  Total Load  Sub Div Code  Dtr No       DTR Name  Feeder No  \
# 0         18       56.39         133.0      18     018-paikan        5.0
# 1         22       20.95         133.0      44     044-KHELMA        2.0
# 2         43      119.91         133.0      46  046-CRAIGPARK        5.0
# 3         44       58.06         133.0      50    050-9BPL II        2.0
# 4         46       48.92         133.0      54      054-BPR 1        9.0
# ..       ...         ...           ...     ...            ...        ...
# 618     2247       33.41           NaN       0            NaN        NaN
# 619     2254        1.00           NaN       0            NaN        NaN
# 620     2255        1.00           NaN       0            NaN        NaN
# 621     2260       19.59           NaN       0            NaN        NaN
# 622     2261        0.98           NaN       0            NaN        NaN
#
#     Capacity   Latitude  Longitude  comparison_column
# ...

# %%
logic
if Dtr no == Dtr No2:
    print(Total Load)

else index ++ (for Dtr No2)

# %% [markdown]
# ## below solutuions are not working for now

# %%
rslt_df = result_2.loc[result_2['Dtr No'].isin(result_2['Dtr No2'])]

# %%
rslt_df
# Out:
#      Dtr No2  Total Load  Sub Div Code  Dtr No                   DTR Name  \
# 0         18       56.39         133.0      18                 018-paikan
# 1         22       20.95         133.0      44                 044-KHELMA
# 2         43      119.91         133.0      46              046-CRAIGPARK
# 3         44       58.06         133.0      50                050-9BPL II
# 4         46       48.92         133.0      54                  054-BPR 1
# ..       ...         ...           ...     ...                        ...
# 301      616       24.68         133.0    2210       BIHARA PT V DDUGJY21
# 305      620       47.58         133.0    2214  NIZ FULBARI PT I DDUGJY21
# 311      629      111.31         133.0    2223       SARASAPUR 1 DDUGJY21
# 318      637        7.59         133.0    2246            DUDPUR LAMARGAM
# 320      641       11.45         133.0    2255  BOROITOLI NEAR DIGABOR TE
#
#      Feeder No Capacity   Latitude  Longitude  comparison_column
# ...

# %%
rslt_df.reset_index(drop= True, inplace = True)

# %%
rslt_df.head(50)
# Out:
#     Dtr No2  Total Load  Sub Div Code  Dtr No  \
# 0        18       56.39         133.0      18
# 1        22       20.95         133.0      44
# 2        43      119.91         133.0      46
# 3        44       58.06         133.0      50
# 4        46       48.92         133.0      54
# 5        47       29.94         133.0      55
# 6        50        9.28         133.0      57
# 7        51       40.01         133.0     102
# 8        52       15.81         133.0     103
# 9        54       26.60         133.0     105
# 10       55       60.66         133.0     106
# 11       57       34.80         133.0     108
# 12       76        8.06         133.0     109
# 13      102      401.32         133.0     110
# 14      103       76.64         133.0     111
# 15      105      446.58         133.0     112
# 16      106      113.98         133.0     114
# 17      108      436.25         133.0     115
# 18      109      117.28         133.0     117
# ...

# %%
# rslt_df.to_csv("rslt_csv.csv")

# %%
# if result_2.loc[result_2['Dtr No'].isin(result_2['Dtr No2'])]:
#     print(rslt_df['Total Load'])
